# %% [markdown]
# # Evolution of actors over time

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_movies = pd.read_pickle("../data/generated/preprocessed/movies.pkl")
df_roles = pd.read_pickle("../data/generated/preprocessed/roles.pkl")
df_actors = pd.read_pickle("../data/generated/preprocessed/actors.pkl")

# %%
df_movies
# Out:
#         wiki_id       fb_id  \
# 0        975900   /m/03vyhn
# 1       3196793   /m/08yl5d
# 2      28463795  /m/0crgdbh
# 3       9363483  /m/0285_cd
# 4        261236   /m/01mrr1
# ...         ...         ...
# 81736  35228177  /m/0j7hxnt
# 81737  34980460  /m/0g4pl34
# 81738   9971909  /m/02pygw1
# 81739    913762   /m/03pcrp
# 81740  12476867  /m/02w7zz8
#
#                                               movie_name movie_release  \
# 0                                         Ghosts of Mars    2001-08-24
# 1      Getting Away with Murder: The JonBenét Ramsey ...    2000-02-16
# 2                                            Brun bitter          1988
# 3                                       White Of The Eye          1987
# 4                                      A Woman in Flames          1983
# ...                                                  ...           ...
# 81736                           Mermaids: The Body Found    2011-03-19
# 81737                                            Knuckle    2011-01-21
# 81738                                  Another Nice Mess    1972-09-22
# 81739  The Super Dimension Fortress Macross II: Lover...    1992-05-21
# 81740                                            Spliced          2002
#
#        movie_revenue  movie_runtime     movie_languages  \
# 0         14010832.0           98.0    English Language
# 1                NaN           95.0    English Language
# 2                NaN           83.0  Norwegian Language
# 3                NaN          110.0    English Language
# 4                NaN          106.0     German Language
# ...              ...            ...                 ...
# 81736            NaN          120.0    English Language
# 81737            NaN           96.0    English Language
# 81738            NaN           66.0    English Language
# 81739            NaN          150.0   Japanese Language
# 81740            NaN           86.0    English Language
#
#                 movie_countries  \
# 0      United States of America
# 1      United States of America
# 2                        Norway
# 3                United Kingdom
# 4                       Germany
# ...                         ...
# 81736  United States of America
# 81737    Ireland,United Kingdom
# 81738  United States of America
# 81739                     Japan
# 81740                    Canada
#
#                                             movie_genres  movie_release_year  \
# 0      Thriller,Science Fiction,Horror,Adventure,Supe...                2001
# 1            Mystery,Biographical film,Drama,Crime Drama                2000
# 2                                    Crime Fiction,Drama                1988
# 3        Thriller,Erotic thriller,Psychological thriller                1987
# 4                                                  Drama                1983
# ...                                                  ...                 ...
# 81736                                              Drama                2011
# 81737                Biographical film,Drama,Documentary                2011
# 81738                                      Satire,Comedy                1972
# 81739  Science Fiction,Japanese Movies,Adventure,Anim...                1992
# 81740                       Thriller,Horror,Slasher,Teen                2002
#
#       fb_movie_id  tomato_score
# 0       /m/03vyhn          22.0
# 1             NaN           NaN
# 2             NaN           NaN
# 3      /m/0285_cd          50.0
# 4             NaN           NaN
# ...           ...           ...
# 81736         NaN           NaN
# 81737  /m/0g4pl34          93.0
# 81738         NaN           NaN
# 81739         NaN           NaN
# 81740         NaN           NaN
#
# [81741 rows x 12 columns]

# %%
df_roles
# Out:
#          wiki_id fb_movie_id     release              character_name  \
# 0         975900   /m/03vyhn  2001-08-24                    Akooshay
# 1         975900   /m/03vyhn  2001-08-24  Lieutenant Melanie Ballard
# 2         975900   /m/03vyhn  2001-08-24         Desolation Williams
# 3         975900   /m/03vyhn  2001-08-24          Sgt Jericho Butler
# 4         975900   /m/03vyhn  2001-08-24             Bashira Kincaid
# ...          ...         ...         ...                         ...
# 450664    913762   /m/03pcrp  1992-05-21                      Elensh
# 450665    913762   /m/03pcrp  1992-05-21                      Hibiki
# 450666  28308153  /m/0cp05t9        1957                         NaN
# 450667  28308153  /m/0cp05t9        1957                         NaN
# 450668  28308153  /m/0cp05t9        1957                         NaN
#
#         actor_age  fb_char_id fb_actor_id
# 0            42.0  /m/0bgchxw  /m/03wcfv7
# 1            27.0   /m/0jys3m   /m/0346l4
# 2            32.0   /m/0jys3g  /m/01vw26l
# 3            33.0  /m/02vchl6   /m/034hyc
# 4            23.0  /m/02vbb3r   /m/01y9xg
# ...           ...         ...         ...
# 450664        NaN  /m/0kr406c   /m/0b_vcv
# 450665       27.0  /m/0kr405_   /m/0bx7_j
# 450666       15.0  /m/0g8ngmc   /m/022g44
# 450667        NaN  /m/0g8ngmj  /m/0g8ngmm
# 450668        NaN  /m/0g8ngmw  /m/0btz19d
#
# [450669 rows x 7 columns]

# %%
df_actors
# Out:
#        fb_actor_id          actor_name actor_birth ethnicity  actor_height  \
# 0       /m/03wcfv7      Wanda De Jesus  1958-08-26       NaN         1.620
# 1        /m/0346l4  Natasha Henstridge  1974-08-15       NaN         1.780
# 2       /m/01vw26l            Ice Cube  1969-06-15       NaN         1.727
# 3        /m/034hyc       Jason Statham  1967-09-12       NaN         1.750
# 4        /m/01y9xg         Clea DuVall  1977-09-25       NaN         1.650
# ...            ...                 ...         ...       ...           ...
# 135756  /m/0kr409z       Violet Bronte         NaN       NaN           NaN
# 135757   /m/0gn4bz       Sonny Byrkett        1954       NaN           NaN
# 135758   /m/0gn4nd       Susan Byrkett        1958       NaN           NaN
# 135759  /m/0kr407h      Hal Cleaveland         NaN       NaN           NaN
# 135760  /m/0g8ngmm    Roberta Paterson         NaN       NaN           NaN
#
#        actor_gender         actor_nationality
# 0                 F  United States of America
# 1                 F                    Canada
# 2                 M  United States of America
# 3                 M            United Kingdom
# 4                 F  United States of America
# ...             ...                       ...
# 135756            F                       NaN
# 135757            M                       NaN
# 135758            F                       NaN
# 135759            M                       NaN
# 135760          NaN                       NaN
#
# [135761 rows x 7 columns]

# %% [markdown]
# ## General actor data

# %%
df_roles_ext = pd.merge(df_roles, df_movies[["movie_release_year", "fb_id", "tomato_score"]], left_on="fb_movie_id", right_on="fb_id")

# %%
df_actor_mins = df_roles_ext[["fb_actor_id", "actor_age", "movie_release_year"]].groupby("fb_actor_id").min()
df_actor_mins.rename(columns = {'actor_age':'debut_age', 'movie_release_year':'debut_year'}, inplace=True)
df_actors = pd.merge(df_actors, df_actor_mins, on="fb_actor_id", how="left")

# %%
df_actor_maxs = df_roles_ext[["fb_actor_id", "actor_age", "movie_release_year"]].groupby("fb_actor_id").max()
df_actor_maxs.rename(columns = {'actor_age':'last_movie_age', 'movie_release_year':'last_movie_year'}, inplace=True)
df_actors = pd.merge(df_actors, df_actor_maxs, on="fb_actor_id", how="left")

# %%
df_actors_in_movies = df_roles.drop_duplicates(subset=["fb_actor_id", "fb_movie_id"])
df_actor_movie_count = df_actors_in_movies[["fb_actor_id"]].groupby("fb_actor_id").size().astype("UInt32")
df_actor_movie_count.name = "movies_count"
df_actors = pd.merge(df_actors, df_actor_movie_count, on="fb_actor_id", how="left")

# %%
df_actor_med = df_roles_ext[["fb_actor_id", "tomato_score"]].groupby("fb_actor_id").median()
df_actor_med.rename(columns = {'tomato_score':'median_tomato_score'}, inplace=True)
df_actors = pd.merge(df_actors, df_actor_med, on="fb_actor_id", how="left")

# %%
df_actors["movies_per_decade"] = (df_actors.movies_count * 10) / (1 + df_actors.last_movie_year - df_actors.debut_year)

# %%
df_actors
# Out:
#        fb_actor_id          actor_name actor_birth ethnicity  actor_height  \
# 0       /m/03wcfv7      Wanda De Jesus  1958-08-26       NaN         1.620
# 1        /m/0346l4  Natasha Henstridge  1974-08-15       NaN         1.780
# 2       /m/01vw26l            Ice Cube  1969-06-15       NaN         1.727
# 3        /m/034hyc       Jason Statham  1967-09-12       NaN         1.750
# 4        /m/01y9xg         Clea DuVall  1977-09-25       NaN         1.650
# ...            ...                 ...         ...       ...           ...
# 135756  /m/0kr409z       Violet Bronte         NaN       NaN           NaN
# 135757   /m/0gn4bz       Sonny Byrkett        1954       NaN           NaN
# 135758   /m/0gn4nd       Susan Byrkett        1958       NaN           NaN
# 135759  /m/0kr407h      Hal Cleaveland         NaN       NaN           NaN
# 135760  /m/0g8ngmm    Roberta Paterson         NaN       NaN           NaN
#
#        actor_gender         actor_nationality  debut_age  debut_year  \
# 0                 F  United States of America       31.0        1990
# 1                 F                    Canada       20.0        1995
# 2                 M  United States of America       22.0        1991
# 3                 M            United Kingdom       30.0        1998
# 4                 F  United States of America       19.0        1997
# ...             ...                       ...        ...         ...
# 135756            F                       NaN        NaN        1992
# 135757            M                       NaN       38.0        1992
# 135758            F                       NaN       34.0        1992
# 135759            M                       NaN        NaN        1992
# 135760          NaN                       NaN        NaN        1957
#
#         last_movie_age  last_movie_year  movies_count  median_tomato_score  \
# 0                 51.0             2009             8                 30.0
# 1                 35.0             2010            20                 30.0
# 2                 42.0             2012            33                 37.0
# 3                 44.0             2012            31                 50.0
# 4                 34.0             2012            31                 53.0
# ...                ...              ...           ...                  ...
# 135756             NaN             1992             1                  NaN
# 135757            38.0             1992             1                  NaN
# 135758            34.0             1992             1                  NaN
# 135759             NaN             1992             1                  NaN
# 135760             NaN             1957             1                  NaN
#
#         movies_per_decade
# 0                     4.0
# 1                    12.5
# 2                    15.0
# 3               20.666667
# 4                  19.375
# ...                   ...
# 135756               10.0
# 135757               10.0
# 135758               10.0
# 135759               10.0
# 135760               10.0
#
# [135761 rows x 14 columns]

# %%
df_actors.movies_per_decade.describe()
# Out:
# count    135296.000000
# mean          8.819366
# std           3.911632
# min           0.208333
# 25%           7.500000
# 50%          10.000000
# 75%          10.000000
# max         183.333333
# Name: movies_per_decade, dtype: float64

# %%
mpd_max = 20
mpd_bins = 10
mpd_bin_size = (mpd_max // mpd_bins)
mpd_actor_counts = []
for ix in range(mpd_bins):
    mpd_actor_counts.append(df_actors.loc[(df_actors.movies_per_decade >= mpd_bin_size*ix) & (df_actors.movies_per_decade < mpd_bin_size*(ix+1))].size)

# %%
for i,v in enumerate(mpd_actor_counts):
    print("[%d, %d[: %d"%(mpd_bin_size*i, mpd_bin_size*(i+1), v))
# Out:
# [0, 2[: 97720
# [2, 4[: 160076
# [4, 6[: 127708
# [6, 8[: 96376
# [8, 10[: 29932
# [10, 12[: 1294104
# [12, 14[: 18564
# [14, 16[: 17500
# [16, 18[: 7602
# [18, 20[: 3220

# %%
without_outlier = df_actors.movies_per_decade.dropna().loc[df_actors.movies_per_decade < 30]
fig, ax = plt.subplots()
ax.set_xlabel("Number of movies played in per decade")
ax.set_ylabel("Number of actors")
ax.set_yscale("log")
ax.set_xticks(range(0, 30, 2))
ax.set_title("Movies per decades")
hist = ax.hist(without_outlier, bins=30)

# %% [raw]
# The number of movies actors play in per decade approximatly follows a power law, except at 10 and 20 movies per decade respectively where we see big spikes. This is expected as this would correspond to series of movies releasing annually and bi-annually

# %% [markdown]
# ## See how the movie ratings of actors evolve over their careers

# %%
df_big_actors = df_actors.loc[df_actors.movies_count >= 10]
df_role_tomato = pd.merge(df_roles_ext, df_big_actors, on="fb_actor_id")
df_roles_ext
# Out:
#          wiki_id fb_movie_id     release              character_name  \
# 0         975900   /m/03vyhn  2001-08-24                    Akooshay
# 1         975900   /m/03vyhn  2001-08-24  Lieutenant Melanie Ballard
# 2         975900   /m/03vyhn  2001-08-24         Desolation Williams
# 3         975900   /m/03vyhn  2001-08-24          Sgt Jericho Butler
# 4         975900   /m/03vyhn  2001-08-24             Bashira Kincaid
# ...          ...         ...         ...                         ...
# 450664    913762   /m/03pcrp  1992-05-21                      Elensh
# 450665    913762   /m/03pcrp  1992-05-21                      Hibiki
# 450666  28308153  /m/0cp05t9        1957                         NaN
# 450667  28308153  /m/0cp05t9        1957                         NaN
# 450668  28308153  /m/0cp05t9        1957                         NaN
#
#         actor_age  fb_char_id fb_actor_id  movie_release_year       fb_id  \
# 0            42.0  /m/0bgchxw  /m/03wcfv7                2001   /m/03vyhn
# 1            27.0   /m/0jys3m   /m/0346l4                2001   /m/03vyhn
# 2            32.0   /m/0jys3g  /m/01vw26l                2001   /m/03vyhn
# 3            33.0  /m/02vchl6   /m/034hyc                2001   /m/03vyhn
# 4            23.0  /m/02vbb3r   /m/01y9xg                2001   /m/03vyhn
# ...           ...         ...         ...                 ...         ...
# 450664        NaN  /m/0kr406c   /m/0b_vcv                1992   /m/03pcrp
# 450665       27.0  /m/0kr405_   /m/0bx7_j                1992   /m/03pcrp
# 450666       15.0  /m/0g8ngmc   /m/022g44                1957  /m/0cp05t9
# 450667        NaN  /m/0g8ngmj  /m/0g8ngmm                1957  /m/0cp05t9
# 450668        NaN  /m/0g8ngmw  /m/0btz19d                1957  /m/0cp05t9
#
#         tomato_score
# 0               22.0
# 1               22.0
# 2               22.0
# 3               22.0
# 4               22.0
# ...              ...
# 450664           NaN
# 450665           NaN
# 450666           NaN
# 450667           NaN
# 450668           NaN
#
# [450669 rows x 10 columns]

# %%
df_role_tomato = df_role_tomato[["fb_movie_id", "fb_actor_id", "tomato_score", "movie_release_year", "debut_year", "median_tomato_score"]].dropna()
df_role_tomato["time_in_career"] = df_role_tomato.movie_release_year - df_role_tomato.debut_year
df_role_tomato["relative_score"] = df_role_tomato.tomato_score - df_role_tomato.median_tomato_score
df_role_tomato[["fb_movie_id", "fb_actor_id", "time_in_career", "relative_score"]]
# Out:
#        fb_movie_id fb_actor_id  time_in_career  relative_score
# 0        /m/03vyhn   /m/0346l4               6            -8.0
# 1       /m/02854l1   /m/0346l4               1           -30.0
# 2        /m/03_gr5   /m/0346l4               9           -26.0
# 6        /m/0346m0   /m/0346l4               3           -21.0
# 8        /m/06wp5n   /m/0346l4               5            23.0
# ...            ...         ...             ...             ...
# 221481   /m/02vdw6  /m/02qdc5h               8            10.0
# 221497   /m/0428s7  /m/027dkny              31            -6.0
# 221498   /m/03bdkd  /m/027dkny              15             1.0
# 221499  /m/02z5kmx  /m/027dkny              28            -1.0
# 221501    /m/0k5px  /m/027dkny              13             2.0
#
# [84748 rows x 4 columns]

# %%
sns.jointplot(x=df_role_tomato.time_in_career, y=df_role_tomato.relative_score, kind="hex")
